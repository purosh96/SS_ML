# %% [markdown]
# <a href="https://colab.research.google.com/github/purosh96/SS_ML/blob/main/GridSearchCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
X,y = make_blobs(n_samples = 1000, centers = 3,cluster_std = 1.4)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn')

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf')

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}

# %%
grid = GridSearchCV(svc,parameters)

# %time grid.fit(X, y)
print(grid.best_params_)
# Out:
# CPU times: user 103 ms, sys: 1.62 ms, total: 105 ms
# Wall time: 104 ms
# {'C': 1, 'kernel': 'linear'}

# %%
model = grid.best_estimator_

# %%
model
# Out:
# SVC(C=1, kernel='linear')

# %%
yfit = model.predict(X)
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X, yfit, clf=model, legend=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
